# %% [markdown]
# Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:

# %% [markdown]
# Scrape the details team India’s international fixtures from bcci.tv.

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
rank = driver.find_elements_by_xpath("//td[@align='center'][1]")
for i in rank[0:30]:
    Rank.append(i.text)

# %%
name = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[2]")
for i in name[0:30]:
    Name.append(i.text)

# %%
artist = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[3]")
for i in artist[0:30]:
    Artist.append(i.text)

# %%
date = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[5]")
for i in date[0:30]:
    Upload_date.append(i.text)

# %%
views = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[4]")
for i in views[0:30]:
    Views.append(i.text)

# %%
d1 = pd.DataFrame({'Rank':Rank,'Name':Name,'Artist':Artist,'Upload_date':Upload_date,'Views':Views})
d1
# Out:
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[22]
# 1    2.                                  "Despacito"[24]
# 2    3.                       "Johny Johny Yes Papa"[25]
# 3    4.                               "Shape of You"[26]
# 4    5.                              "See You Again"[27]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]
# 6    7.                                "Uptown Funk"[31]
# 7    8.                                  "Bath Song"[32]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[33]
# 9   10.                              "Gangnam Style"[34]
# 10  11.                "Phonics Song with Two Words"[36]
# 11  12.                                      "Sugar"[37]
# 12  13.                                      "Sorry"[38]
# 13  14.                             "Dame Tu Cosita"[39]
# 14  15.                                       "Roar"[40]
# ...

# %%
driver.close()

# %% [markdown]
# Question 2

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.bcci.tv/")

# %%
all_fixtures=driver.find_element_by_xpath("//ul[@class='scroll-grid-phab block-list-4 block-list-3-wide block-list-3-desk block-list-2-tab block-list-1-phab js-slide slider__list match-slider']/li[22]/a")
url = all_fixtures.get_attribute('href')
url
# Out:
# 'https://www.bcci.tv/international/fixtures'

# %%
driver.get(url)

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
mt = driver.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']")
for i in mt:
    Match_title.append(i.text)
len(Match_title)
# Out:
# 0

# %%
series= driver.find_elements_by_xpath("//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
for i in series:
    Series.append(i.text)
len(Series)
# Out:
# 0

# %%
place = driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
for i in place:
    Place.append(i.text)
len(Place)
# Out:
# 0

# %%
date = driver.find_elements_by_xpath("//span[@class='fixture__date']")
month= driver.find_elements_by_xpath("//span[@class='fixture__month']")
for i in range(0,14):
    Date.append(date[i].text+' '+month[i].text)
len(Date)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-c57e45cc52d5> in <module>
#       2 month= driver.find_elements_by_xpath("//span[@class='fixture__month']")
#       3 for i in range(0,14):
# ----> 4     Date.append(date[i].text+' '+month[i].text)
#       5 len(Date)
#
# IndexError: list index out of range

# %%
time = driver.find_elements_by_xpath("//span[@class='fixture__time']")
for i in time:
    Time.append(i.text)
len(Time)
# Out:
# 12

# %%
d2 = pd.DataFrame({'Match_title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Time':Time})
d2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-187ec7d8874c> in <module>
# ----> 1 d2 = pd.DataFrame({'Match_title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Time':Time})
#       2 d2
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# ...

# %%
driver.close()

# %% [markdown]
# Question 3

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.guru99.com/")

# %%
selenium = driver.find_element_by_xpath("//ul[@class='menu']/li[3]/a")
selenium_url = selenium.get_attribute('href')
selenium_url
# Out:
# 'https://www.guru99.com/selenium-tutorial.html'

# %%
driver.get(selenium_url)

# %%
exceptions = driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']")
url = exceptions.get_attribute('href')
url
# Out:
# 'https://www.guru99.com/exception-handling-selenium.html'

# %%
driver.get(url)

# %%
Name=[]
Description=[]

# %%
for i in range(2,43):
    name= driver.find_element_by_xpath(f"//table[@class='table table-striped']/tbody/tr[{i}]/td[1]")
    description = driver.find_element_by_xpath(f"//table[@class='table table-striped']/tbody/tr[{i}]/td[2]")
    Name.append(name.text)
    Description.append(description.text)

# %%
Name
# Out:
# ['ElementNotVisibleException',
#  'ElementNotSelectableException',
#  'NoSuchElementException',
#  'NoSuchFrameException',
#  'NoAlertPresentException',
#  'NoSuchWindowException',
#  'StaleElementReferenceException',
#  'SessionNotFoundException',
#  'TimeoutException',
#  'WebDriverException',
#  'ConnectionClosedException',
#  'ElementClickInterceptedException',
#  'ElementNotInteractableException',
#  'ErrorInResponseException',
#  'ErrorHandler.UnknownServerException',
#  'ImeActivationFailedException',
#  'ImeNotAvailableException',
#  'InsecureCertificateException',
#  'InvalidArgumentException',
#  'InvalidCookieDomainException',
#  'InvalidCoordinatesException',
#  'InvalidElementStateExceptio',
#  'InvalidSessionIdException',
#  'InvalidSwitchToTargetException',
#  'JavascriptException',
#  'JsonException',
#  'NoSuchAttributeException',
#  'MoveTargetOutOfBoundsException',
#  'NoSuchContextException',
#  'NoSuchCookieException',
#  'NotFoundException',
# ...

# %%
Description
# Out:
# ['This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  'This Exception occurs if an element could not be found.',
#  'This Exception occurs if the frame target to be switched to does not exist.',
#  'This Exception occurs when you switch to no presented alert.',
#  'This Exception occurs if the window target to be switch does not exist.',
#  'This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  'The WebDriver is acting after you quit the browser.',
#  "Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn't found in the specified time.",
#  'This Exception takes place when the WebDriver is acting right after you close the browser.',
# ...

# %%
d3 = pd.DataFrame({'Name':Name,'Description':Description})
d3
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %%
driver.close()

# %% [markdown]
# Question 4

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("http://statisticstimes.com/")

# %%
india = driver.find_element_by_xpath("//div[@class='dropdown'][2]/div/a[3]")
india_url = india.get_attribute('href')
india_url
# Out:
# 'http://statisticstimes.com/economy/india-statistics.php'

# %%
driver.get(india_url)

# %%
gdp_list = driver.find_element_by_xpath("//div[@style='float:left;background-color:seashell;width:400px;height:800px;']/ul/li")
gdp_list.click()

# %%
Rank=[]
State=[]
GSDP1=[]
GSDP2=[]
Share=[]
GDP=[]

# %%
for i in range(1,34):
    Rank.append(driver.find_element_by_xpath(f"//tbody/tr[@role='row'][{i}]/td[1]").text)
    State.append(driver.find_element_by_xpath(f"//tbody/tr[@role='row'][{i}]/td[2]").text)
    GSDP1.append(driver.find_element_by_xpath(f"//tbody/tr[@role='row'][{i}]/td[3]").text)
    GSDP2.append(driver.find_element_by_xpath(f"//tbody/tr[@role='row'][{i}]/td[4]").text)
    Share.append(driver.find_element_by_xpath(f"//tbody/tr[@role='row'][{i}]/td[5]").text)
    GDP.append(driver.find_element_by_xpath(f"//tbody/tr[@role='row'][{i}]/td[6]").text)

# %%
d4=pd.DataFrame({'Rank':Rank,'State':State,'GSDP(19-20)':GSDP1,'GSDP(18-19)':GSDP2,'Share':Share,'GDP':GDP})
d4
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19)   Share      GDP
# 0     1                Maharashtra           -   2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%  240.726
# 3     4                    Gujarat           -   1,502,899   7.96%  228.290
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%  226.806
# 5     6                West Bengal   1,253,832   1,089,898   5.77%  165.556
# 6     7                  Rajasthan   1,020,989     942,586   4.99%  143.179
# 7     8             Andhra Pradesh     972,782     862,957   4.57%  131.083
# 8     9                  Telangana     969,604     861,031   4.56%  130.791
# 9    10             Madhya Pradesh     906,672     809,592   4.29%  122.977
# 10   11                     Kerala           -     781,653   4.14%  118.733
# ...

# %%
driver.close()

# %% [markdown]
# Q5

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://github.com/")

# %%
details = driver.find_elements_by_xpath("//details[@class='HeaderMenu-details details-overlay details-reset width-full']")
details
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="081b51f5b8304105811d467eb43b7783", element="afe494be-f09e-466e-9520-cfcbac7b2d41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="081b51f5b8304105811d467eb43b7783", element="48b90295-278e-4d2e-a76d-16b7bfc66af6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="081b51f5b8304105811d467eb43b7783", element="186260d1-eb0f-42da-9cde-08be7eb820ea")>]

# %%
details[1].click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-127-dda5af5e0783> in <module>
# ----> 1 details[1].click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
trending = driver.find_element_by_xpath("//ul[@class='list-style-none mb-3']/li[3]/a")
trending

# %%
trending.click()

# %%
Title=[]
Description=[]
Cont_count=[]
l_used=[]

# %%
rep = driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
url = []
for i in rep:
    url.append(i.get_attribute('href'))
len(url)
# Out:
# 0

# %%
for i in url:
    driver.get(i)
    
    title = driver.find_element_by_xpath("//strong[@class='mr-2 flex-self-stretch']/a")
    Title.append(title.text)
    
    try:
        Description.append(driver.find_element_by_xpath("//div[@class='Box-body px-5 pb-5']").text)
    except NoSuchElementException:
        Description.append('-')
        
    try:
        Cont_count.append(driver.find_element_by_xpath("//div[@class='BorderGrid BorderGrid--spacious']/div[4]/div/h2/a/span").get_attribute('title'))
    except NoSuchElementException:
        Cont_count.append('-')
        
    lang_i=[]
    lang = driver.find_elements_by_xpath("//span[@class='color-text-primary text-bold mr-1']")
    for j in lang:
        lang_i.append(j.text)
    l_used.append(lang_i)

# %%
d5 = pd.DataFrame({'Title':Title,'Description':Description,'Contributors_count':Cont_count,'Languages_used':l_used})
d5
# Out:
# Empty DataFrame
# Columns: [Title, Description, Contributors_count, Languages_used]
# Index: []

# %%
driver.close()

# %%
Question 6

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.billboard.com/")

# %%
hot_100 = driver.find_elements_by_xpath("//li[@class='header__subnav__item']/a")
url=[]
for i in hot_100:
    url.append(i.get_attribute('href'))

# %%
url
# Out:
# ['https://www.billboardwomeninmusic.com/',
#  'https://www.billboardevents.com/',
#  'https://www.billboard.com/charts/hot-100',
#  'https://www.billboard.com/charts/billboard-200',
#  'https://www.billboard.com/charts/billboard-global-200',
#  'https://www.billboard.com/chart-beat',
#  'https://www.billboard.com/hondastage']

# %%
driver.get(url[2])

# %%
S_name=[]
A_name=[]
L_w_r=[]
P_r=[]
W_o_b=[]

# %%
s = driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
for i in s:
    S_name.append(i.text)
len(S_name)
# Out:
# 100

# %%
a = driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
for i in a:
    A_name.append(i.text)
len(A_name)
# Out:
# 100

# %%
lwr = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in lwr:
    L_w_r.append(i.text)
len(L_w_r)
# Out:
# 100

# %%
pr = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in pr:
    P_r.append(i.text)
len(P_r)
# Out:
# 100

# %%
wob = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in wob:
    W_o_b.append(i.text)
len(W_o_b)
# Out:
# 100

# %%
d6 = pd.DataFrame({'Song name':S_name,'Artist name':A_name,'Last week rank':L_w_r,'Peak rank':P_r,'Weeks on board':W_o_b})
d6
# Out:
#                             Song name  \
# 0                              Butter
# 1                            Good 4 U
# 2                          Levitating
# 3                             Peaches
# 4                 Leave The Door Open
# ..                                ...
# 95           Things A Man Oughta Know
# 96                      Country Again
# 97  Drunk (And I Don't Wanna Go Home)
# 98                     If You Want To
# 99                       Seeing Green
#
#                                        Artist name Last week rank Peak rank  \
# 0                                              BTS              1         1
# 1                                   Olivia Rodrigo              2         1
# 2                        Dua Lipa Featuring DaBaby              3         2
# 3   Justin Bieber Featuring Daniel Caesar & Giveon              6         1
# 4         Silk Sonic (Bruno Mars & Anderson .Paak)              4         1
# ...

# %%
driver.close()

# %% [markdown]
# Question 7

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.naukri.com/")

# %%
rec = driver.find_element_by_xpath("//ul[@class='midSec menu']/li[2]/a")
url = rec.get_attribute('href')
url
# Out:
# 'https://www.naukri.com/recruiters'

# %%
driver.get(url)

# %%
inp = driver.find_element_by_xpath("//input[@class='sugInp']")
inp.send_keys('Data science')

# %%
search = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']")
search.click()

# %%
Name=[]
Designation=[]
Company=[]
Skills = []
Location=[]

# %%
name = driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
for i in name:
    Name.append(i.text)
len(Name)
# Out:
# 50

# %%
des = driver.find_elements_by_xpath("//span[@class='ellipsis clr'][1]")
for i in des:
    Designation.append(i.text)
len(Designation)
# Out:
# 50

# %%
company = driver.find_elements_by_xpath("//a[@class='ellipsis'][2]")
for i in company:
    Company.append(i.text)
len(Company)
# Out:
# 50

# %%
parent = driver.find_elements_by_xpath("//div[@class='vcard']")
for i in parent:
    try:
        loc = i.find_element_by_xpath(".//small[@class='ellipsis']")
        Location.append(loc.text)
    except NoSuchElementException:
        Location.append('-')
len(Location)
# Out:
# 50

# %%
skills = driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for i in skills:
    Skills.append(i.text)
len(Skills)
# Out:
# 50

# %%
d7 = pd.DataFrame({'Name':Name,'Designation':Designation,'Company name':Company,'Location':Location,'Skills hired for':Skills})
d7
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                    Ruchi Dhote
# 14                             Mahesh Babu Channa
# 15                                   Kapil Devang
# 16                                  Manisha Yadav
# 17                                    Riya Rajesh
# ...

# %%
driver.close()

# %% [markdown]
# Question 8

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
Bname=[]
Aname=[]
Vs=[]
Publisher=[]
Genre=[]

# %%
for i in range(1,101):
    Bname.append(driver.find_element_by_xpath(f"//tbody/tr[{i}]/td[2]").text)
    Aname.append(driver.find_element_by_xpath(f"//tbody/tr[{i}]/td[3]").text)
    Vs.append(driver.find_element_by_xpath(f"//tbody/tr[{i}]/td[4]").text)
    Publisher.append(driver.find_element_by_xpath(f"//tbody/tr[{i}]/td[5]").text)
    Genre.append(driver.find_element_by_xpath(f"//tbody/tr[{i}]/td[6]").text)

# %%
d8 = pd.DataFrame({'Book name':Bname,
                  'Author name':Aname,
                  'Volumes sold':Vs,
                  'Publisher':Publisher,
                  'Genre':Genre})
d8
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# Question 9

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
Name=[]
Ys=[]
Genre=[]
Rt=[]
Ratings= []
Votes=[]

# %%
name = driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
for i in name:
    Name.append(i.text)
len(Name)
# Out:
# 100

# %%
ys = driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
for i in ys:
    Ys.append(i.text)
len(Ys)
# Out:
# 100

# %%
genre = driver.find_elements_by_xpath("//span[@class='genre']")
for i in genre:
    Genre.append(i.text)
len(Genre)
# Out:
# 100

# %%
rt = driver.find_elements_by_xpath("//span[@class='runtime']")
for i in rt:
    Rt.append(i.text)
len(Rt)
# Out:
# 100

# %%
rating = driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")
for i in rating:
    Ratings.append(i.text)
len(Ratings)
# Out:
# 100

# %%
votes = driver.find_elements_by_xpath("//span[@name='nv']")
for i in votes:
    Votes.append(i.text)
len(Votes)
# Out:
# 100

# %%
d9 = pd.DataFrame({'Name':Name,
                  'Year span':Ys,
                  'Genre':Genre,
                  'Runtime':Rt,
                  'Rating':Ratings,
                  'Votes':Votes})
d9
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     Runtime Rating      Votes
# 0    57 min    9.3  1,825,442
# ...

# %%
driver.close()

# %% [markdown]
# Question 10

# %%
# opening the automated window and the desired webpage
driver = webdriver.Chrome("chromedriver.exe") 
driver.get("https://archive.ics.uci.edu/")

# %%
ad= driver.find_elements_by_xpath("//span[@class='whitetext']/a")
url=[]
for i in ad:
    url.append(i.get_attribute('href'))
url
# Out:
# ['https://archive.ics.uci.edu/ml/about.html',
#  'https://archive.ics.uci.edu/ml/citation_policy.html',
#  'https://archive.ics.uci.edu/ml/donation_policy.html',
#  'https://archive.ics.uci.edu/ml/contact.html',
#  'https://archive.ics.uci.edu/ml/datasets.php']

# %%
driver.get(url[4])

# %%
Name=[]
Type=[]
Task=[]
Atype=[]
Noi=[]
Noa=[]
Year=[]

# %%
for i in range(2,587):
    Name.append(driver.find_element_by_xpath(f"//table[@border='1']/tbody/tr[{i}]/td[1]").text)
    Type.append(driver.find_element_by_xpath(f"//table[@border='1']/tbody/tr[{i}]/td[2]").text)
    Task.append(driver.find_element_by_xpath(f"//table[@border='1']/tbody/tr[{i}]/td[3]").text)
    Atype.append(driver.find_element_by_xpath(f"//table[@border='1']/tbody/tr[{i}]/td[4]").text)
    Noi.append(driver.find_element_by_xpath(f"//table[@border='1']/tbody/tr[{i}]/td[5]").text)
    Noa.append(driver.find_element_by_xpath(f"//table[@border='1']/tbody/tr[{i}]/td[6]").text)
    Year.append(driver.find_element_by_xpath(f"//table[@border='1']/tbody/tr[{i}]/td[7]").text)

# %%
d10 = pd.DataFrame({'Dataset name':Name,
                   'Dataset type':Type,
                   'Task':Task,
                   'Attribute type':Atype,
                   'Number of instances':Noi,
                   'Number of Attributes':Noa,
                   'Year':Year})
d10
# Out:
#                                    Dataset name                Dataset type  \
# 0                                       Abalone               Multivariate
# 1                                         Adult               Multivariate
# 2                                     Annealing               Multivariate
# 3                  Anonymous Microsoft Web Data
# 4                                    Arrhythmia               Multivariate
# ..                                          ...                         ...
# 580                  Wisesight Sentiment Corpus         Multivariate, Text
# 581    AI4I 2020 Predictive Maintenance Dataset  Multivariate, Time-Series
# 582                            Dry Bean Dataset               Multivariate
# 583            in-vehicle coupon recommendation               Multivariate
# 584                         Gait Classification               Multivariate
#
#                                               Task  \
# ...

# %%
driver.close()
